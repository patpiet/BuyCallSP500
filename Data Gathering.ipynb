# %%
import pandas as pd
import yfinance as yf

# %%
# Get max range data of SPX500
df = yf.download("SPY")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500   25.438091
# 1993-02-01   43.968750   44.250000   43.968750   44.250000   25.619019
# 1993-02-02   44.218750   44.375000   44.125000   44.343750   25.673307
# 1993-02-03   44.406250   44.843750   44.375000   44.812500   25.944689
# 1993-02-04   44.968750   45.093750   44.468750   45.000000   26.053240
# ...                ...         ...         ...         ...         ...
# 2022-06-17  365.510010  369.380005  362.170013  365.859985  365.859985
# 2022-06-21  371.890015  376.529999  371.809998  375.070007  375.070007
# 2022-06-22  370.619995  378.720001  370.179993  374.390015  374.390015
# 2022-06-23  376.640015  378.829987  372.890015  378.059998  378.059998
# 2022-06-24  381.399994  390.089996  381.369995  390.079987  390.079987
#
#                Volume
# Date
# 1993-01-29    1003200
# 1993-02-01     480500
# 1993-02-02     201300
# ...

# %%
# Library for the technical indicators
import ta

# %%
# Simple Moving Average Indicator (SMA)
df['SMA'] = ta.trend.SMAIndicator(df['Close'], window=14).sma_indicator()

# %%
# Moving Average Convergence Divergence (MACD)
df['MACD'] = ta.trend.MACD(df['Close'], window_sign=14).macd()

# %%
# Relative Strength Index (RSI)
df['RSI'] = ta.momentum.RSIIndicator(df['Close'], window=14).rsi()

# %%
# Percentage Price Oscillator indicator (PPO)
ta.momentum.ppo(df['Close'], window_sign=14)
# Out:
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
#                 ...
# 2022-06-17   -2.645449
# 2022-06-21   -2.680905
# 2022-06-22   -2.693907
# 2022-06-23   -2.598366
# 2022-06-24   -2.244280
# Name: PPO_12_26, Length: 7405, dtype: float64

# %%
# Average Directional Index (ADX)
df['ADX'] = ta.trend.ADXIndicator(df['High'], df['Low'], df['Close'], window=14).adx()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\User\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)

# %%
# Williams Percent Range (%R)
df['R%'] = ta.momentum.WilliamsRIndicator(df['High'], df['Low'], df['Close'], lbp=14).williams_r()

# %%
# Accumulation/Distribution Line Indicator (A/D)
df['ADI'] = ta.volume.acc_dist_index(df['High'], df['Low'], df['Close'], df['Volume'])

# %%
#  Aroon Oscillator (AO)
df['AI'] = ta.trend.AroonIndicator(df['Close'], window=14).aroon_indicator()

# %%
# Commodity Channel Index (CCI)
df['CCI'] = ta.trend.CCIIndicator(df['High'], df['Low'], df['Close'], window=14).cci()

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500   25.438091
# 1993-02-01   43.968750   44.250000   43.968750   44.250000   25.619019
# 1993-02-02   44.218750   44.375000   44.125000   44.343750   25.673307
# 1993-02-03   44.406250   44.843750   44.375000   44.812500   25.944689
# 1993-02-04   44.968750   45.093750   44.468750   45.000000   26.053240
# ...                ...         ...         ...         ...         ...
# 2022-06-17  365.510010  369.380005  362.170013  365.859985  365.859985
# 2022-06-21  371.890015  376.529999  371.809998  375.070007  375.070007
# 2022-06-22  370.619995  378.720001  370.179993  374.390015  374.390015
# 2022-06-23  376.640015  378.829987  372.890015  378.059998  378.059998
# 2022-06-24  381.399994  390.089996  381.369995  390.079987  390.079987
#
#                Volume         SMA       MACD        RSI        ADX         R%  \
# Date
# ...

# %%
df.to_csv('SPYIndicators.csv')
